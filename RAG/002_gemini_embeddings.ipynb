# %% [markdown]
# # Gemini API - Embeddings
# Replica de `002_embeddings.ipynb` (VoyageAI) usando la API de Gemini, siguiendo la misma estructura de cliente que `002_gemini_prompt_evals.ipynb`.

# %%
# Install google-genai lib
# %pip install google-genai python-dotenv

# %%
# Load env variables and create client
from dotenv import load_dotenv
from google import genai
from google.genai import types

load_dotenv()

client = genai.Client()
embedding_model = "gemini-embedding-001"

# %%
# Chunk by section
import re


def chunk_by_section(document_text):
    pattern = r"\n## "
    return re.split(pattern, document_text)

# %%
# Embedding Generation
def generate_embedding(text, model=embedding_model, task_type="RETRIEVAL_QUERY"):
    result = client.models.embed_content(
        model=model,
        contents=text,
        config=types.EmbedContentConfig(task_type=task_type),
    )

    return result.embeddings[0].values

# %%
with open("./report.md", "r") as f:
    text = f.read()

chunks = chunk_by_section(text)

generate_embedding(chunks[0])
